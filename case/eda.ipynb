# %%
import pandas as pd
from pandas_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('data.csv', sep=";")
data.head()
# Out:
#        Y  Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  Feature 6  \
# 0  13500         23      46986        1.0         90          1          0
# 1  13750         23      72937        1.0         90          1          0
# 2  13950         24      41711        1.0         90          1          0
# 3  14950         26      48000        1.0         90          0          0
# 4  13750         30      38500        1.0         90          0          0
#
#    Feature 7  Feature 8  Feature 9
# 0       2000          3       1165
# 1       2000          3       1165
# 2       2000          3       1165
# 3       2000          3       1165
# 4       2000          3       1170

# %%
profile = ProfileReport(data, title="Data Profile")
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.3.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-10-04 15:12:45.084091&quot;&gt;&lt;title&gt;Data Profile&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("raw_data_profile.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sns.kdeplot(data=data["Y"].to_numpy())
plt.show()

# %%
sns.kdeplot(data=np.log(data["Y"].to_numpy()))
plt.show()

# %%
data.corr()
# Out:
#                   Y  Feature 1  Feature 2  Feature 3  Feature 4  Feature 5  \
# Y          1.000000  -0.876590  -0.569960  -0.000113   0.314990   0.108905
# Feature 1 -0.876590   1.000000   0.505672   0.040223  -0.156622  -0.108150
# Feature 2 -0.569960   0.505672   1.000000   0.471233  -0.333538  -0.080503
# Feature 3 -0.000113   0.040223   0.471233   1.000000  -0.492348  -0.019695
# Feature 4  0.314990  -0.156622  -0.333538  -0.492348   1.000000   0.058712
# Feature 5  0.108905  -0.108150  -0.080503  -0.019695   0.058712   1.000000
# Feature 6  0.033081   0.031717  -0.081854  -0.100631   0.013144  -0.019335
# Feature 7  0.165067  -0.133182   0.302150   0.849744   0.050884   0.034921
# Feature 8  0.185326  -0.148359  -0.036197  -0.032324   0.092424   0.085243
# Feature 9  0.581198  -0.470253  -0.028598   0.561679   0.089614   0.057929
#
#            Feature 6  Feature 7  Feature 8  Feature 9
# Y           0.033081   0.165067   0.185326   0.581198
# ...

# %%
corr_mtrx = data.corr().to_numpy()
sns.heatmap(data=corr_mtrx)
plt.show()

# %%
upper_tri = np.where(np.triu(np.ones(corr_mtrx.shape),k=1).astype(np.bool), corr_mtrx)
upper_tri
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23840\726429493.py in <module>
# ----> 1 upper_tri = np.where(np.triu(np.ones(corr_mtrx.shape),k=1).astype(np.bool), corr_mtrx)
#       2 upper_tri
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %% [markdown]
# ##### Fjerner Feature 3 som er 71% missing og sterkt korrelert med feature 2

# %% [markdown]
# qq

# %%
qq =
